# %% [markdown]
# # Install and import Libraries

# %%
import numpy as np

# %%
import pandas as pd

# %%
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score

# %%
from xgboost import XGBClassifier

# %%
import os, sys

# %% [markdown]
# # Read the data

# %%
df=pd.read_csv('parkinsons.data')
df.head()
# Out:
#              name  MDVP:Fo(Hz)  MDVP:Fhi(Hz)  MDVP:Flo(Hz)  MDVP:Jitter(%)  \
# 0  phon_R01_S01_1      119.992       157.302        74.997         0.00784
# 1  phon_R01_S01_2      122.400       148.650       113.819         0.00968
# 2  phon_R01_S01_3      116.682       131.111       111.555         0.01050
# 3  phon_R01_S01_4      116.676       137.871       111.366         0.00997
# 4  phon_R01_S01_5      116.014       141.781       110.655         0.01284
#
#    MDVP:Jitter(Abs)  MDVP:RAP  MDVP:PPQ  Jitter:DDP  MDVP:Shimmer  ...  \
# 0           0.00007   0.00370   0.00554     0.01109       0.04374  ...
# 1           0.00008   0.00465   0.00696     0.01394       0.06134  ...
# 2           0.00009   0.00544   0.00781     0.01633       0.05233  ...
# 3           0.00009   0.00502   0.00698     0.01505       0.05492  ...
# 4           0.00011   0.00655   0.00908     0.01966       0.06425  ...
#
#    Shimmer:DDA      NHR     HNR  status      RPDE       DFA   spread1  \
# ...

# %% [markdown]
# # Column description

# %% [raw]
# Column Descriptions with MDVP Prefix:
# MDVP:Fo(Hz): Fundamental frequency in Hertz.
# MDVP:Fhi(Hz): Highest fundamental frequency.
# MDVP:Flo(Hz): Lowest fundamental frequency.
# MDVP:Jitter(%): Percentage of frequency variation.
# MDVP:Jitter(Abs): Absolute frequency variation.
# MDVP:RAP: Relative Amplitude Perturbation.
# MDVP:PPQ: Period Perturbation Quotient.
# Jitter:DDP: Difference in the pitch period between cycles.
# MDVP:Shimmer: Measures amplitude variation.

# %% [markdown]
# # Get the features and labels from the DataFrame

# %%
# Features = all columns except for 'status' 
# Labels = thosin the 'status' column 
# Array form

features=df.loc[:,df.columns!='status'].values[:,1:]
labels=df.loc[:,'status'].values

# %%
# Get the label count of each (O and 1) in labels

print(labels[labels==1].shape[0], labels[labels==0].shape[0])
# Out:
# 147 48

# %%
# MinMax scaling (normalization), range [-1,1]

scaler = MinMaxScaler((-1,1))
x=scaler.fit_transform(features)
y=labels

# %%
Split the dataset
x_train,x_test,y_train,y_test=train_test_split(x, y, test_size=0.2, random_state=7)
